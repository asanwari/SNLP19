# %% [markdown]
# # 1.1 (a)

# %%
# coding: utf-8
# SNLP - SoSe 2019 - ASSINGMENT VI

import math
import re
from collections import defaultdict, Counter
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib qt 


def tokenize(text):
    "List all the word tokens (consecutive letters) in a text. Normalize to lowercase."
    return re.findall('[a-z]+', text.lower())

def word_ngrams(tokenized_text, n):
    return [tuple(tokenized_text[i:i + n]) for i in range(0, len(tokenized_text)-n+1)]


class ngram_LM:
    """A class to represent a language model."""

    def __init__(self, n, ngram_counts, vocab, unk=False):
        """"Make a n-gram language model, given a vocab and
            data structure for n-gram counts."""

        self.n = n

        self.vocab = vocab

        self.V = len(vocab)

        self.ngram_counts = ngram_counts

    # YOUR CODE HERE
    # START BY MAKING THE RIGHT COUNTS FOR THIS PARTICULAR self.n
        # for unigrams, we only need total word count
        if n == 1:
            self.total_count = sum(self.ngram_counts.values())
        # for bigrams, we need total count wrt each word. In our language, it is history count.
        elif n == 2:
            self.history_count = Counter()
            for k, v in self.ngram_counts.items():
                self.history_count[k[0]] = self.history_count[k[0]] + v
            # since we only count for the first word in the tuple, we will always
            # miss counting </s>. However, since the frequency of </s> is the same
            # as the frequency of <s>, we can simply assign it equal to it.
            self.history_count['</s>'] = self.history_count['<s>']



    def estimate_prob(self, history, word):
        """Estimate probability of a word given a history."""
        if history == '':
            # unigram
            word_frequency = self.ngram_counts[tuple([word])]
            return word_frequency/self.total_count

        else:
            # bigram
            word_frequency = self.ngram_counts[tuple([history, word])]
            history_count = self.history_count[history]
            if history_count == 0:
                return 0
            return word_frequency/history_count


    def estimate_smoothed_prob(self, history, word, alpha = 0.5):
        """Estimate probability of a word given a history with Lidstone smoothing."""

        if history == '':
            # unigram
            word_frequency = self.ngram_counts[tuple([word])]
            return (word_frequency + alpha)/(alpha*self.V +self.total_count)

        else:
            # bigram
            word_frequency = self.ngram_counts[tuple([history, word])]
            history_count = self.history_count[history]
            return (word_frequency + alpha)/(alpha*self.V + history_count)

    def getN1plus(self, word):
        # currently implemented for N1+(.,w)
        count = 0
        for v in self.vocab:
            if self.ngram_counts[tuple([v,word])] > 0:
                count = count + 1
        return count

    
    def kneser_Ney_smoothing(self, history, word):
        # currently implemented only for history = ''
        
        # out of vocab case
        if word not in self.vocab:
            return 1/self.V
        numerator = self.getN1plus(word)
        denominator = len(self.ngram_counts)
        return numerator/denominator
    


    def logP(self, history, word):
        """Return base-2 log probablity."""
        prob = self.estimate_smoothed_prob(history, word)
        log_prob = math.log(prob, 2)
        return log_prob


    def score_sentence(self, sentence):
        """Given a sentence, return score."""
        log_prob_sum = 0
        for i in range(len(sentence)):
            history = sentence[i][0]
            word = sentence[i][1]
            log_prob = self.logP(history, word)
            log_prob_sum += log_prob
        normalized_log_prob_sum = (-1 / len(sentence)) * log_prob_sum
        return normalized_log_prob_sum


    def test_LM(self):
        """Test whether or not the probability mass sums up to one."""

        precision = 10**-8

        if self.n == 1:

            P_sum = sum(self.estimate_prob('', w) for w in self.vocab)

            assert abs(1.0 - P_sum) < precision, 'Probability mass does not sum up to one.'

        elif self.n == 2:
            histories = ['the', 'in', 'at', 'blue', 'white']

            for h in histories:

                P_sum = sum(self.estimate_prob(h, w) for w in self.vocab)

                assert abs(1.0 - P_sum) < precision, 'Probability mass does not sum up to one for history' + h

        print('TEST SUCCESSFUL!')



    def test_smoohted_LM(self):
        """Test whether or not the smoothed probability mass sums up to one."""
        precision = 10**-8

        if self.n == 1:

            P_sum = sum(self.estimate_smoothed_prob('', w) for w in self.vocab)

            assert abs(1.0 - P_sum) < precision, 'Probability mass does not sum up to one.'

        elif self.n == 2:
            histories = ['the', 'in', 'at', 'blue', 'white']

            for h in histories:

                P_sum = sum(self.estimate_smoothed_prob(h, w) for w in self.vocab)

                assert abs(1.0 - P_sum) < precision, 'Probability mass does not sum up to one for history' + h

        print('TEST SUCCESSFUL!')


    def perplexity(self, test_corpus, alpha):

        likelihood = 0
        for sentence in test_corpus:
            try:
                if self.n == 1:
                    prob = self.estimate_smoothed_prob('', sentence[0], alpha)
                elif self.n ==2:
                    prob = self.estimate_smoothed_prob(sentence[0], sentence[1], alpha)
                likelihood += math.log2(prob)
            except:
                if alpha == 0:
                    continue 

        perplexity = math.pow(2, (-1*likelihood)/len(test_corpus))
        return perplexity

# %%
# main
filename= 'corpus.sent.en.train'
with open(filename, encoding='utf-8', errors='replace') as f:
    # read entire file
    text = f.read() 

# tokenize it
tokenized_text = tokenize(text)
unigrams = Counter(word_ngrams(tokenized_text,1))
unigram_vocabulary = list(unigrams.keys())
unigram_vocabulary = [i[0] for i in unigram_vocabulary]

bigrams = Counter(word_ngrams(tokenized_text,2))
bigram_vocabulary = [i for i in unigram_vocabulary]
bigram_vocabulary.extend(['<s>','</s>'])

# %%
words = ['york', 'matter']
unigram_LM = ngram_LM(1, unigrams, unigram_vocabulary)
bigram_LM = ngram_LM(2, bigrams, bigram_vocabulary)
for word in words:
    print('\n\n------ For Word "{}"------\n\n'.format(word))
    print('N(w) is {}'.format(unigram_LM.ngram_counts[tuple([word])]))
    print('N1+(.,w) is {}'.format(bigram_LM.getN1plus(word)))
    
    P_ML = unigram_LM.estimate_prob('',word)
    log2P_ML = -math.log(P_ML, 2)
    print('-log2P_ML(w) is {}'.format(log2P_ML))
    
    P_Lids = unigram_LM.estimate_smoothed_prob('',word,1)
    log2P_Lids =  -math.log(P_Lids, 2)
    print('-log2PLids(w) is {}'.format(log2P_Lids))
    
    P_kn = bigram_LM.kneser_Ney_smoothing('',word)
    log2P_kn = -math.log(P_kn, 2)
    print('-log2Pkn(w) is {}'.format(log2P_kn))
# Out:
# ------ For Word "york"------
#
#
# N(w) is 2374
# ('the', 'york') has count 1
# ('of', 'york') has count 6
# ('and', 'york') has count 2
# ('at', 'york') has count 1
# ('from', 'york') has count 2
# ('new', 'york') has count 2358
# ('facts', 'york') has count 1
# ('blue', 'york') has count 1
# ('thenew', 'york') has count 2
# N1+(.,w) is 9
# -log2P_ML(w) is 12.258374283571047
# -log2PLids(w) is 12.268770360977008
# ('the', 'york') has count 1
# ('of', 'york') has count 6
# ('and', 'york') has count 2
# ('at', 'york') has count 1
# ('from', 'york') has count 2
# ('new', 'york') has count 2358
# ('facts', 'york') has count 1
# ('blue', 'york') has count 1
# ('thenew', 'york') has count 2
# -log2Pkn(w) is 18.06307025575544
#
#
# ------ For Word "matter"------
#
#
# N(w) is 2367
# ('it', 'matter') has count 29
# ('to', 'matter') has count 25
# ('the', 'matter') has count 405
# ('of', 'matter') has count 23
# ('that', 'matter') has count 150
# ('is', 'matter') has count 1
# ('will', 'matter') has count 11
# ('elections', 'matter') has count 2
# ('and', 'matter') has count 4
# ('as', 'matter') has count 1
# ('this', 'matter') has count 49
# ('a', 'matter') has count 628
# ('security', 'matter') has count 1
# ('where', 'matter') has count 1
# ('or', 'matter') has count 1
# ('surface', 'matter') has count 1
# ('their', 'matter') has count 1
# ('both', 'matter') has count 1
# ('who', 'matter') has count 1
# ('policies', 'matter') has count 1
# ('with', 'matter') has count 1
# ('investment', 'matter') has count 1
# ('gdp', 'matter') has count 1
# ('growth', 'matter') has count 2
# ('could', 'matter') has count 4
# ('on', 'matter') has count 1
# ('years', 'matter') has count 1
# ('would', 'matter') has count 3
# ('do', 'matter') has count 10
# ('over', 'matter') has count 1
# ('not', 'matter') has count 61
# ('words', 'matter') has count 3
# ('they', 'matter') has count 1
# ('states', 'matter') has count 1
# ('understood', 'matter') has count 1
# ('state', 'matter') has count 1
# ('all', 'matter') has count 4
# ('international', 'matter') has count 2
# ('political', 'matter') has count 2
# ('its', 'matter') has count 1
# ('time', 'matter') has count 2
# ('might', 'matter') has count 3
# ('one', 'matter') has count 4
# ('large', 'matter') has count 1
# ('enough', 'matter') has count 1
# ('difference', 'matter') has count 1
# ('between', 'matter') has count 1
# ('can', 'matter') has count 2
# ('also', 'matter') has count 12
# ('europe', 'matter') has count 1
# ('by', 'matter') has count 1
# ('may', 'matter') has count 4
# ('what', 'matter') has count 6
# ('recent', 'matter') has count 1
# ('no', 'matter') has count 357
# ('european', 'matter') has count 1
# ('t', 'matter') has count 46
# ('another', 'matter') has count 44
# ('different', 'matter') has count 23
# ('should', 'matter') has count 7
# ('still', 'matter') has count 3
# ('questions', 'matter') has count 1
# ('culture', 'matter') has count 1
# ('foreign', 'matter') has count 1
# ('internal', 'matter') has count 4
# ('economic', 'matter') has count 1
# ('thus', 'matter') has count 1
# ('cooperation', 'matter') has count 1
# ('professional', 'matter') has count 1
# ('technical', 'matter') has count 3
# ('you', 'matter') has count 1
# ('little', 'matter') has count 4
# ('normal', 'matter') has count 1
# ('how', 'matter') has count 1
# ('only', 'matter') has count 1
# ('assets', 'matter') has count 1
# ('personal', 'matter') has count 4
# ('indeed', 'matter') has count 1
# ('them', 'matter') has count 1
# ('primary', 'matter') has count 1
# ('love', 'matter') has count 1
# ('true', 'matter') has count 1
# ('rates', 'matter') has count 3
# ('any', 'matter') has count 2
# ('banks', 'matter') has count 1
# ('democracy', 'matter') has count 1
# ('resources', 'matter') has count 1
# ('painful', 'matter') has count 2
# ('really', 'matter') has count 26
# ('incentives', 'matter') has count 4
# ('ever', 'matter') has count 1
# ('lives', 'matter') has count 4
# ('such', 'matter') has count 1
# ('private', 'matter') has count 9
# ('germany', 'matter') has count 1
# ('principles', 'matter') has count 1
# ('empirical', 'matter') has count 1
# ('proper', 'matter') has count 1
# ('difficult', 'matter') has count 1
# ('longer', 'matter') has count 3
# ('things', 'matter') has count 1
# ('context', 'matter') has count 1
# ('values', 'matter') has count 1
# ('crucial', 'matter') has count 2
# ('anything', 'matter') has count 1
# ('minor', 'matter') has count 4
# ('cities', 'matter') has count 1
# ('legal', 'matter') has count 3
# ('polish', 'matter') has count 1
# ('ultimately', 'matter') has count 2
# ('markets', 'matter') has count 1
# ('important', 'matter') has count 7
# ('complex', 'matter') has count 2
# ('institutions', 'matter') has count 2
# ('summit', 'matter') has count 1
# ('policy', 'matter') has count 1
# ('latter', 'matter') has count 1
# ('historical', 'matter') has count 1
# ('hopes', 'matter') has count 1
# ('does', 'matter') has count 7
# ('voices', 'matter') has count 1
# ('roma', 'matter') has count 1
# ('italy', 'matter') has count 1
# ('actually', 'matter') has count 2
# ('serious', 'matter') has count 7
# ('bilateral', 'matter') has count 1
# ('based', 'matter') has count 1
# ('small', 'matter') has count 11
# ('differences', 'matter') has count 3
# ('debt', 'matter') has count 1
# ('symbols', 'matter') has count 2
# ('plant', 'matter') has count 2
# ('election', 'matter') has count 1
# ('sex', 'matter') has count 1
# ('family', 'matter') has count 2
# ('whole', 'matter') has count 13
# ('subject', 'matter') has count 18
# ('appropriate', 'matter') has count 1
# ('influence', 'matter') has count 1
# ('controversial', 'matter') has count 2
# ('ideas', 'matter') has count 5
# ('troublesome', 'matter') has count 1
# ('neighbors', 'matter') has count 1
# ('light', 'matter') has count 1
# ('morality', 'matter') has count 1
# ('nor', 'matter') has count 1
# ('moscow', 'matter') has count 1
# ('entire', 'matter') has count 1
# ('diplomatic', 'matter') has count 1
# ('conditions', 'matter') has count 2
# ('clearly', 'matter') has count 1
# ('dollars', 'matter') has count 1
# ('pure', 'matter') has count 1
# ('commercial', 'matter') has count 1
# ('uk', 'matter') has count 1
# ('size', 'matter') has count 1
# ('g', 'matter') has count 1
# ('benefits', 'matter') has count 1
# ('simple', 'matter') has count 13
# ('geopolitical', 'matter') has count 1
# ('fundamental', 'matter') has count 3
# ('priorities', 'matter') has count 1
# ('committee', 'matter') has count 1
# ('numbers', 'matter') has count 2
# ('capabilities', 'matter') has count 1
# ('innovation', 'matter') has count 1
# ('vital', 'matter') has count 2
# ('funders', 'matter') has count 1
# ('decisions', 'matter') has count 1
# ('sister', 'matter') has count 1
# ('quantities', 'matter') has count 1
# ('factors', 'matter') has count 1
# ('shape', 'matter') has count 1
# ('practical', 'matter') has count 5
# ('distributed', 'matter') has count 1
# ('details', 'matter') has count 1
# ('separate', 'matter') has count 1
# ('easy', 'matter') has count 7
# ('ties', 'matter') has count 1
# ('choices', 'matter') has count 2
# ('pressing', 'matter') has count 1
# ('settled', 'matter') has count 1
# ('unresolved', 'matter') has count 1
# ('images', 'matter') has count 1
# ('organic', 'matter') has count 5
# ('inert', 'matter') has count 1
# ('everyday', 'matter') has count 1
# ('straightforward', 'matter') has count 5
# ('flow', 'matter') has count 1
# ('hair', 'matter') has count 1
# ('forgotten', 'matter') has count 1
# ('dead', 'matter') has count 1
# ('unacceptable', 'matter') has count 1
# ('actions', 'matter') has count 1
# ('strange', 'matter') has count 1
# ('dark', 'matter') has count 12
# ('intentions', 'matter') has count 2
# ('supposedly', 'matter') has count 1
# ('ordinary', 'matter') has count 1
# ('organizes', 'matter') has count 1
# ('agendas', 'matter') has count 1
# ('visible', 'matter') has count 1
# ('supplies', 'matter') has count 1
# ('judicial', 'matter') has count 1
# ('liberalization', 'matter') has count 1
# ('solid', 'matter') has count 1
# ('advertising', 'matter') has count 1
# ('minds', 'matter') has count 1
# ('academic', 'matter') has count 1
# ('complicated', 'matter') has count 1
# ('strategies', 'matter') has count 1
# ('petty', 'matter') has count 1
# ('roots', 'matter') has count 1
# ('urgent', 'matter') has count 8
# ('personalized', 'matter') has count 1
# ('koreans', 'matter') has count 1
# ('perceptions', 'matter') has count 1
# ('deeds', 'matter') has count 1
# ('evolutionary', 'matter') has count 1
# ('caribbean', 'matter') has count 1
# ('subtle', 'matter') has count 1
# ('evolution', 'matter') has count 1
# ('epic', 'matter') has count 1
# ('simpler', 'matter') has count 1
# ('published', 'matter') has count 1
# ('intricate', 'matter') has count 1
# ('vegetable', 'matter') has count 1
# ('narratives', 'matter') has count 2
# ('finances', 'matter') has count 1
# ('biology', 'matter') has count 1
# ('trivial', 'matter') has count 3
# ('ratings', 'matter') has count 1
# ('odd', 'matter') has count 1
# ('brutally', 'matter') has count 1
# ('relationships', 'matter') has count 1
# ('geography', 'matter') has count 1
# ('printed', 'matter') has count 2
# ('conditional', 'matter') has count 1
# ('inanimate', 'matter') has count 1
# ('projections', 'matter') has count 1
# ('dried', 'matter') has count 1
# ('delicate', 'matter') has count 2
# ('pivotal', 'matter') has count 1
# ('hereditary', 'matter') has count 1
# ('myths', 'matter') has count 1
# ('subjective', 'matter') has count 1
# ('contexts', 'matter') has count 1
# ('personalities', 'matter') has count 1
# ('brute', 'matter') has count 1
# ('affronts', 'matter') has count 1
# ('offing', 'matter') has count 1
# ('laughing', 'matter') has count 2
# ('infective', 'matter') has count 3
# ('biases', 'matter') has count 1
# ('specialist', 'matter') has count 1
# ('worldly', 'matter') has count 1
# ('negligible', 'matter') has count 1
# ('terminology', 'matter') has count 1
# ('summits', 'matter') has count 1
# ('metaphors', 'matter') has count 1
# ('fecal', 'matter') has count 1
# ('weighty', 'matter') has count 1
# ('particulate', 'matter') has count 5
# ('lunar', 'matter') has count 1
# ('pesky', 'matter') has count 1
# ('vomited', 'matter') has count 1
# ('nonliving', 'matter') has count 1
# ('pomham', 'matter') has count 1
# ('sedimentary', 'matter') has count 1
# N1+(.,w) is 269
# -log2P_ML(w) is 12.262634512478337
# -log2PLids(w) is 12.27302879345373
# ('it', 'matter') has count 29
# ('to', 'matter') has count 25
# ('the', 'matter') has count 405
# ('of', 'matter') has count 23
# ('that', 'matter') has count 150
# ('is', 'matter') has count 1
# ('will', 'matter') has count 11
# ('elections', 'matter') has count 2
# ('and', 'matter') has count 4
# ('as', 'matter') has count 1
# ('this', 'matter') has count 49
# ('a', 'matter') has count 628
# ('security', 'matter') has count 1
# ('where', 'matter') has count 1
# ('or', 'matter') has count 1
# ('surface', 'matter') has count 1
# ('their', 'matter') has count 1
# ('both', 'matter') has count 1
# ('who', 'matter') has count 1
# ('policies', 'matter') has count 1
# ('with', 'matter') has count 1
# ('investment', 'matter') has count 1
# ('gdp', 'matter') has count 1
# ('growth', 'matter') has count 2
# ('could', 'matter') has count 4
# ('on', 'matter') has count 1
# ('years', 'matter') has count 1
# ('would', 'matter') has count 3
# ('do', 'matter') has count 10
# ('over', 'matter') has count 1
# ('not', 'matter') has count 61
# ('words', 'matter') has count 3
# ('they', 'matter') has count 1
# ('states', 'matter') has count 1
# ('understood', 'matter') has count 1
# ('state', 'matter') has count 1
# ('all', 'matter') has count 4
# ('international', 'matter') has count 2
# ('political', 'matter') has count 2
# ('its', 'matter') has count 1
# ('time', 'matter') has count 2
# ('might', 'matter') has count 3
# ('one', 'matter') has count 4
# ('large', 'matter') has count 1
# ('enough', 'matter') has count 1
# ('difference', 'matter') has count 1
# ('between', 'matter') has count 1
# ('can', 'matter') has count 2
# ('also', 'matter') has count 12
# ('europe', 'matter') has count 1
# ('by', 'matter') has count 1
# ('may', 'matter') has count 4
# ('what', 'matter') has count 6
# ('recent', 'matter') has count 1
# ('no', 'matter') has count 357
# ('european', 'matter') has count 1
# ('t', 'matter') has count 46
# ('another', 'matter') has count 44
# ('different', 'matter') has count 23
# ('should', 'matter') has count 7
# ('still', 'matter') has count 3
# ('questions', 'matter') has count 1
# ('culture', 'matter') has count 1
# ('foreign', 'matter') has count 1
# ('internal', 'matter') has count 4
# ('economic', 'matter') has count 1
# ('thus', 'matter') has count 1
# ('cooperation', 'matter') has count 1
# ('professional', 'matter') has count 1
# ('technical', 'matter') has count 3
# ('you', 'matter') has count 1
# ('little', 'matter') has count 4
# ('normal', 'matter') has count 1
# ('how', 'matter') has count 1
# ('only', 'matter') has count 1
# ('assets', 'matter') has count 1
# ('personal', 'matter') has count 4
# ('indeed', 'matter') has count 1
# ('them', 'matter') has count 1
# ('primary', 'matter') has count 1
# ('love', 'matter') has count 1
# ('true', 'matter') has count 1
# ('rates', 'matter') has count 3
# ('any', 'matter') has count 2
# ('banks', 'matter') has count 1
# ('democracy', 'matter') has count 1
# ('resources', 'matter') has count 1
# ('painful', 'matter') has count 2
# ('really', 'matter') has count 26
# ('incentives', 'matter') has count 4
# ('ever', 'matter') has count 1
# ('lives', 'matter') has count 4
# ('such', 'matter') has count 1
# ('private', 'matter') has count 9
# ('germany', 'matter') has count 1
# ('principles', 'matter') has count 1
# ('empirical', 'matter') has count 1
# ('proper', 'matter') has count 1
# ('difficult', 'matter') has count 1
# ('longer', 'matter') has count 3
# ('things', 'matter') has count 1
# ('context', 'matter') has count 1
# ('values', 'matter') has count 1
# ('crucial', 'matter') has count 2
# ('anything', 'matter') has count 1
# ('minor', 'matter') has count 4
# ('cities', 'matter') has count 1
# ('legal', 'matter') has count 3
# ('polish', 'matter') has count 1
# ('ultimately', 'matter') has count 2
# ('markets', 'matter') has count 1
# ('important', 'matter') has count 7
# ('complex', 'matter') has count 2
# ('institutions', 'matter') has count 2
# ('summit', 'matter') has count 1
# ('policy', 'matter') has count 1
# ('latter', 'matter') has count 1
# ('historical', 'matter') has count 1
# ('hopes', 'matter') has count 1
# ('does', 'matter') has count 7
# ('voices', 'matter') has count 1
# ('roma', 'matter') has count 1
# ('italy', 'matter') has count 1
# ('actually', 'matter') has count 2
# ('serious', 'matter') has count 7
# ('bilateral', 'matter') has count 1
# ('based', 'matter') has count 1
# ('small', 'matter') has count 11
# ('differences', 'matter') has count 3
# ('debt', 'matter') has count 1
# ('symbols', 'matter') has count 2
# ('plant', 'matter') has count 2
# ('election', 'matter') has count 1
# ('sex', 'matter') has count 1
# ('family', 'matter') has count 2
# ('whole', 'matter') has count 13
# ('subject', 'matter') has count 18
# ('appropriate', 'matter') has count 1
# ('influence', 'matter') has count 1
# ('controversial', 'matter') has count 2
# ('ideas', 'matter') has count 5
# ('troublesome', 'matter') has count 1
# ('neighbors', 'matter') has count 1
# ('light', 'matter') has count 1
# ('morality', 'matter') has count 1
# ('nor', 'matter') has count 1
# ('moscow', 'matter') has count 1
# ('entire', 'matter') has count 1
# ('diplomatic', 'matter') has count 1
# ('conditions', 'matter') has count 2
# ('clearly', 'matter') has count 1
# ('dollars', 'matter') has count 1
# ('pure', 'matter') has count 1
# ('commercial', 'matter') has count 1
# ('uk', 'matter') has count 1
# ('size', 'matter') has count 1
# ('g', 'matter') has count 1
# ('benefits', 'matter') has count 1
# ('simple', 'matter') has count 13
# ('geopolitical', 'matter') has count 1
# ('fundamental', 'matter') has count 3
# ('priorities', 'matter') has count 1
# ('committee', 'matter') has count 1
# ('numbers', 'matter') has count 2
# ('capabilities', 'matter') has count 1
# ('innovation', 'matter') has count 1
# ('vital', 'matter') has count 2
# ('funders', 'matter') has count 1
# ('decisions', 'matter') has count 1
# ('sister', 'matter') has count 1
# ('quantities', 'matter') has count 1
# ('factors', 'matter') has count 1
# ('shape', 'matter') has count 1
# ('practical', 'matter') has count 5
# ('distributed', 'matter') has count 1
# ('details', 'matter') has count 1
# ('separate', 'matter') has count 1
# ('easy', 'matter') has count 7
# ('ties', 'matter') has count 1
# ('choices', 'matter') has count 2
# ('pressing', 'matter') has count 1
# ('settled', 'matter') has count 1
# ('unresolved', 'matter') has count 1
# ('images', 'matter') has count 1
# ('organic', 'matter') has count 5
# ('inert', 'matter') has count 1
# ('everyday', 'matter') has count 1
# ('straightforward', 'matter') has count 5
# ('flow', 'matter') has count 1
# ('hair', 'matter') has count 1
# ('forgotten', 'matter') has count 1
# ('dead', 'matter') has count 1
# ('unacceptable', 'matter') has count 1
# ('actions', 'matter') has count 1
# ('strange', 'matter') has count 1
# ('dark', 'matter') has count 12
# ('intentions', 'matter') has count 2
# ('supposedly', 'matter') has count 1
# ('ordinary', 'matter') has count 1
# ('organizes', 'matter') has count 1
# ('agendas', 'matter') has count 1
# ('visible', 'matter') has count 1
# ('supplies', 'matter') has count 1
# ('judicial', 'matter') has count 1
# ('liberalization', 'matter') has count 1
# ('solid', 'matter') has count 1
# ('advertising', 'matter') has count 1
# ('minds', 'matter') has count 1
# ('academic', 'matter') has count 1
# ('complicated', 'matter') has count 1
# ('strategies', 'matter') has count 1
# ('petty', 'matter') has count 1
# ('roots', 'matter') has count 1
# ('urgent', 'matter') has count 8
# ('personalized', 'matter') has count 1
# ('koreans', 'matter') has count 1
# ('perceptions', 'matter') has count 1
# ('deeds', 'matter') has count 1
# ('evolutionary', 'matter') has count 1
# ('caribbean', 'matter') has count 1
# ('subtle', 'matter') has count 1
# ('evolution', 'matter') has count 1
# ('epic', 'matter') has count 1
# ('simpler', 'matter') has count 1
# ('published', 'matter') has count 1
# ('intricate', 'matter') has count 1
# ('vegetable', 'matter') has count 1
# ('narratives', 'matter') has count 2
# ('finances', 'matter') has count 1
# ('biology', 'matter') has count 1
# ('trivial', 'matter') has count 3
# ('ratings', 'matter') has count 1
# ('odd', 'matter') has count 1
# ('brutally', 'matter') has count 1
# ('relationships', 'matter') has count 1
# ('geography', 'matter') has count 1
# ('printed', 'matter') has count 2
# ('conditional', 'matter') has count 1
# ('inanimate', 'matter') has count 1
# ('projections', 'matter') has count 1
# ('dried', 'matter') has count 1
# ('delicate', 'matter') has count 2
# ('pivotal', 'matter') has count 1
# ('hereditary', 'matter') has count 1
# ('myths', 'matter') has count 1
# ('subjective', 'matter') has count 1
# ('contexts', 'matter') has count 1
# ('personalities', 'matter') has count 1
# ('brute', 'matter') has count 1
# ('affronts', 'matter') has count 1
# ('offing', 'matter') has count 1
# ('laughing', 'matter') has count 2
# ('infective', 'matter') has count 3
# ('biases', 'matter') has count 1
# ('specialist', 'matter') has count 1
# ('worldly', 'matter') has count 1
# ('negligible', 'matter') has count 1
# ('terminology', 'matter') has count 1
# ('summits', 'matter') has count 1
# ('metaphors', 'matter') has count 1
# ('fecal', 'matter') has count 1
# ('weighty', 'matter') has count 1
# ('particulate', 'matter') has count 5
# ('lunar', 'matter') has count 1
# ('pesky', 'matter') has count 1
# ('vomited', 'matter') has count 1
# ('nonliving', 'matter') has count 1
# ('pomham', 'matter') has count 1
# ('sedimentary', 'matter') has count 1
# -log2Pkn(w) is 13.16153289464113
